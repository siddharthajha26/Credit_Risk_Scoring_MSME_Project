# %%
import joblib
import os

# Save the model
model_file = "credit_risk_scorecard_model.pkl"
joblib.dump(your_trained_model, model_file)

# Create folder structure to save in GitHub repo
os.makedirs("artifacts/models", exist_ok=True)
os.rename(model_file, "artifacts/models/" + model_file)
